# %%
import sys
sys.path.append("..")
import src.demo as demo
import torch

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
demo.demonstration(rotation = 35, ef = 0.6, deformation=False, initial_contrast=4000, device=device)
