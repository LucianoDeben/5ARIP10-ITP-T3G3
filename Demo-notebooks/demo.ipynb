# %%
import sys
sys.path.append("..")
import src.demo as demo
import torch

# Check if GPU is available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
deformation = False

# %%
model = demo.load_model(deformation=deformation, device=device)
volumes, targets = demo.get_demo_data()
demo.demonstration(volumes, targets, model, rotation = 0, ef = 0.6, deformation=deformation, initial_contrast=4000, device=device)
