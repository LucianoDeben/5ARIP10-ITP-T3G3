# %%
import sys
sys.path.append("..")
import src.training

# %%
src.training.trainModel(3,50,True)
# Out:
# c:\Users\Sven\anaconda3\envs\torch\Lib\site-packages\monai\transforms\io\array.py:259: UserWarning: Failed to read ..\data081\HCC-TACE-Seg\HCC_081\300\image\LICENSE with exception:
# File is missing DICOM File Meta Information header or the 'DICM' prefix is missing from the header. Use force=True to force reading..
#   img = reader.read(filename)
# c:\Users\Sven\anaconda3\envs\torch\Lib\site-packages\torch\_tensor.py:1418: UserWarning: Using a target size (torch.Size([1, 256, 256])) that is different to the input size (torch.Size([1, 1, 256, 256])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   ret = func(*args, **kwargs)
# [1/50] - Loss: 0.06780196726322174
# [2/50] - Loss: 0.019967736676335335
# [3/50] - Loss: 0.05053773894906044
# [4/50] - Loss: 0.05349436402320862
# [5/50] - Loss: 0.041021037846803665
# [6/50] - Loss: 0.023433750495314598
# [7/50] - Loss: 0.013540050014853477
# [8/50] - Loss: 0.027194470167160034
# ...
